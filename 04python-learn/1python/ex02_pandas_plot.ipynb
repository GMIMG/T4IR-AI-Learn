# %%
import pandas as pd
persions_dict = { 'Name': ['김성필', '양은희', '이재은', '신춘호'],
                  'Gender': ['남자', '여자', '여자', '남자'],
                  'Age' : [46,24,25,33],
                  'job' : ['개발자', '개발자', '학생', '개발자']
                }

# %%
df = pd.DataFrame(persions_dict)
df.head()
# Out:
#   Name Gender  Age  job
# 0  김성필     남자   46  개발자
# 1  양은희     여자   24  개발자
# 2  이재은     여자   25   학생
# 3  신춘호     남자   33  개발자

# %%
df = pd.read_excel("c:/ai/workspace/data/peoples.xlsx", encoding="utf-8")
df.head()
# Out:
#     이름 성별  키[cm]  몸무게[Kg]
# 0  김성필  남  176.5     71.5
# 1  김민재  남  180.0     78.0
# 2  박은미  여  164.0     64.0
# 3  박성희  여  164.0     64.0
# 4  김이동  남  164.0     58.0

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fl = fm.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
plt.rc('font',family=fl)

plt.figure(figsize=(20,10))

font_dic={"family": fl, "size":30}
plt.rc("font", **font_dic)

plt.stem(df['이름'][0:10], df['키[cm]'][0:10])
plt.show()

# %%
plt.figure(figsize=(10,10))

font_dic={"family": fl, "size":8}
plt.rc("font", **font_dic)

plt.stem(df['이름'], df['키[cm]'])
plt.show()
