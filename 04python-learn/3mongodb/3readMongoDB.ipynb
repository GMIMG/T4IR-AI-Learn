# %%
from pymongo import MongoClient
from gridfs import GridFS
from gridfs import GridFSBucket

# %%
from PIL import Image
from io import BytesIO

# %%
db = MongoClient().python_test

# %%
fs = GridFS(db)

# %%
list(db.fs.files.find())
# Out:
# [{'_id': ObjectId('5de4cc5dc5e221be89212e29'),
#   'filename': 'test.txt',
#   'md5': '0b97c2704cfb0e1892bb47a0b62bef96',
#   'chunkSize': 261120,
#   'length': 35,
#   'uploadDate': datetime.datetime(2019, 12, 2, 8, 33, 34, 69000)},
#  {'_id': ObjectId('5de70317d44159c261476cd2'),
#   'filename': 'test.jpg',
#   'metadata': {'contentType': 'image/jpg'},
#   'chunkSize': 261120,
#   'md5': 'f295c0485e36d3f04689d45b5278c034',
#   'length': 26526,
#   'uploadDate': datetime.datetime(2019, 12, 4, 0, 52, 10, 639000)},
#  {'_id': ObjectId('5de71145aa3bda2f76742061'),
#   'filename': 'test.jpg',
#   'metadata': {'contentType': 'image/jpg'},
#   'chunkSize': 261120,
#   'md5': 'f295c0485e36d3f04689d45b5278c034',
#   'length': 26526,
#   'uploadDate': datetime.datetime(2019, 12, 4, 1, 52, 5, 421000)}]

# %%
file_detail = db.fs.files.find()[1]

# %%
file_detail['filename']
# Out:
# 'test.jpg'

# %%
file_detail['metadata']['contentType']
# Out:
# 'image/jpg'

# %%
f = fs.get_last_version(filename=file_detail['filename'])

# %%
data = f.read()

# %%
from IPython.display import display

# %%
image = Image.open(BytesIO(data))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332 at 0x2565FD0BC18>
