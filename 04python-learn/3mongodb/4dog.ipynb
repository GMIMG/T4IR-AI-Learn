# %%
from pymongo import MongoClient
from gridfs import GridFS
from gridfs import GridFSBucket

# %%
db = MongoClient().python_test

# %%
fs = GridFS(db)

# %%
import urllib.request

# %%
url = 'https://i.ytimg.com/vi/YylkHRXVsV4/maxresdefault.jpg'

# %%
image_type = url.split('.')[-1]

# %%
image_name = url.split('/')[-1]

# %%
content_type = 'image/{}'.format(image_type)

# %%
image = urllib.request.urlopen(url).read()

# %%
from IPython.display import display

# %%
from PIL import Image

# %%
from io import BytesIO

# %%
Image.open(BytesIO(image))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x17EA6A425F8>

# %%
bucket = GridFSBucket(db)

# %%
grid_in = bucket.open_upload_stream(
            'test.jpg', metadata={'contentType': content_type})

# %%
grid_in.write(image)

# %%
grid_in.close()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-35-7f635115f57c> in <module>
# ----> 1 grid_in.close()
#
# ~\Anaconda3\lib\site-packages\gridfs\grid_file.py in close(self)
#     319         """
#     320         if not self._closed:
# --> 321             self.__flush()
#     322             object.__setattr__(self, "_closed", True)
#     323
#
# ~\Anaconda3\lib\site-packages\gridfs\grid_file.py in __flush(self)
#     295         """
#     296         try:
# --> 297             self.__flush_buffer()
#     298
#     299             if "md5" in self._file:
#
# ~\Anaconda3\lib\site-packages\gridfs\grid_file.py in __flush_buffer(self)
#     287         """Flush the buffer contents out to a chunk.
#     288         """
# --> 289         self.__flush_data(self._buffer.getvalue())
#     290         self._buffer.close()
#     291         self._buffer = StringIO()
#
# ...

# %%
MongoClient().close()
