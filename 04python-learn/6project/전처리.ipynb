# %%
import pandas as pd

# %%
re = pd.read_csv('result.csv')
re
# Out:
#         Unnamed: 0  Unnamed: 0.1      id        date   route_id    vh_id  \
# 0                0             0       0  2019-10-15  405136001  7997025
# 1                1             1       1  2019-10-15  405136001  7997025
# 2                2             2       2  2019-10-15  405136001  7997025
# 3                3             3       3  2019-10-15  405136001  7997025
# 4                4             4     181  2019-10-15  405136001  7997034
# 5                5             5     182  2019-10-15  405136001  7997034
# 6                6             6     183  2019-10-15  405136001  7997034
# 7                7             7     184  2019-10-15  405136001  7997034
# 8                8             8     539  2019-10-15  405136001  7997040
# 9                9             9     540  2019-10-15  405136001  7997040
# 10              10            10     541  2019-10-15  405136001  7997040
# 11              11            11     542  2019-10-15  405136001  7997040
# ...

# %%
cc = pd.concat([re.iloc[:,3],re.iloc[:,10:12],re.iloc[:,16:],re.iloc[:,15]],axis = 1)
cc
# Out:
#               date now_arrive_time  distance     기온(°C)  누적강수량(mm)   풍속(m/s)  \
# 0       2019-10-15             06시     266.0  15.526667        0.0  1.706667
# 1       2019-10-15             06시     333.0  15.526667        0.0  1.706667
# 2       2019-10-15             06시     415.0  15.526667        0.0  1.706667
# 3       2019-10-15             06시     578.0  15.526667        0.0  1.706667
# 4       2019-10-15             06시     578.0  15.526667        0.0  1.706667
# 5       2019-10-15             06시     244.0  15.526667        0.0  1.706667
# 6       2019-10-15             06시     415.0  15.526667        0.0  1.706667
# 7       2019-10-15             06시     578.0  15.526667        0.0  1.706667
# 8       2019-10-15             06시     417.0  15.526667        0.0  1.706667
# 9       2019-10-15             06시     334.0  15.526667        0.0  1.706667
# 10      2019-10-15             06시     550.0  15.526667        0.0  1.706667
# ...

# %%
cc['rain']=0
cc.loc[ (cc['누적강수량(mm)']!=0) ,['rain'] ] = 1 #12~17시

# %%
w = pd.DataFrame(cc['풍속(m/s)'].groupby([cc['date'],cc['now_arrive_time']]).mean())
w.mean()[0]
# Out:
# 2.8918403123961474

# %%
cc['wind'] = 0

# %%
w = pd.DataFrame(cc['풍속(m/s)'].groupby([cc['date'],cc['now_arrive_time']]).mean())
cc['wind'] = 0
cc.loc[(cc['풍속(m/s)'] > w.mean()[0]) ,['wind']] = 1

# %%
cc
# Out:
#               date now_arrive_time  distance     기온(°C)  누적강수량(mm)   풍속(m/s)  \
# 0       2019-10-15             06시     266.0  15.526667        0.0  1.706667
# 1       2019-10-15             06시     333.0  15.526667        0.0  1.706667
# 2       2019-10-15             06시     415.0  15.526667        0.0  1.706667
# 3       2019-10-15             06시     578.0  15.526667        0.0  1.706667
# 4       2019-10-15             06시     578.0  15.526667        0.0  1.706667
# 5       2019-10-15             06시     244.0  15.526667        0.0  1.706667
# 6       2019-10-15             06시     415.0  15.526667        0.0  1.706667
# 7       2019-10-15             06시     578.0  15.526667        0.0  1.706667
# 8       2019-10-15             06시     417.0  15.526667        0.0  1.706667
# 9       2019-10-15             06시     334.0  15.526667        0.0  1.706667
# 10      2019-10-15             06시     550.0  15.526667        0.0  1.706667
# ...

# %%
import matplotlib as mpl
import matplotlib.pylab as plt
from matplotlib import font_manager, rc
# %matplotlib inline
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
plt.plot(cc.groupby('count').size())
